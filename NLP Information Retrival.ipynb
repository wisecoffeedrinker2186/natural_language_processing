# %%
import nltk
nltk.download('gutenberg')
nltk.download('brown')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
nltk.download('treebank')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.corpus import stopwords,treebank
from nltk.stem import *
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import gutenberg
import pandas as pd
import re
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\atind\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\atind\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\atind\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\atind\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\atind\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\atind\AppData\Roaming\nltk_data...
# ...

# %%
gutenberg.raw('shakespeare-caesar.txt')
# Out:
# "[The Tragedie of Julius Caesar by William Shakespeare 1599]\n\n\nActus Primus. Scoena Prima.\n\nEnter Flauius, Murellus, and certaine Commoners ouer the Stage.\n\n  Flauius. Hence: home you idle Creatures, get you home:\nIs this a Holiday? What, know you not\n(Being Mechanicall) you ought not walke\nVpon a labouring day, without the signe\nOf your Profession? Speake, what Trade art thou?\n  Car. Why Sir, a Carpenter\n\n   Mur. Where is thy Leather Apron, and thy Rule?\nWhat dost thou with thy best Apparrell on?\nYou sir, what Trade are you?\n  Cobl. Truely Sir, in respect of a fine Workman, I am\nbut as you would say, a Cobler\n\n   Mur. But what Trade art thou? Answer me directly\n\n   Cob. A Trade Sir, that I hope I may vse, with a safe\nConscience, which is indeed Sir, a Mender of bad soules\n\n   Fla. What Trade thou knaue? Thou naughty knaue,\nwhat Trade?\n  Cobl. Nay I beseech you Sir, be not out with me: yet\nif you be out Sir, I can mend you\n\n   Mur. What mean'st thou by t
# ...

# %%
text = gutenberg.sents('shakespeare-caesar.txt')[3]
text
# Out:
# ['Enter',
#  'Flauius',
#  ',',
#  'Murellus',
#  ',',
#  'and',
#  'certaine',
#  'Commoners',
#  'ouer',
#  'the',
#  'Stage',
#  '.']

# %%
sentence= " ".join(text)
sentence
# Out:
# 'Enter Flauius , Murellus , and certaine Commoners ouer the Stage .'

# %%
lower_text = sentence.lower()
tokinized_words = nltk.word_tokenize(lower_text)
punctuation = [',', '.', "\'", '-', "'s", '"', "``", "''","[","]","?",":"]
clean_words = [i for i in tokinized_words if i not in punctuation]

# %%
sentence= " ".join(clean_words)
sentence
# Out:
# 'enter flauius murellus and certaine commoners ouer the stage'

# %% [markdown]
# #### Using nltk's POS tagging

# %%
tagged_sent = pos_tag(word_tokenize(sentence), tagset="universal")
tagged_sent
# Out:
# [('enter', 'NOUN'),
#  ('flauius', 'NOUN'),
#  ('murellus', 'NOUN'),
#  ('and', 'CONJ'),
#  ('certaine', 'NOUN'),
#  ('commoners', 'NOUN'),
#  ('ouer', 'VERB'),
#  ('the', 'DET'),
#  ('stage', 'NOUN')]

# %%
# sentence="he who does the work is the worker"
pos_tag(word_tokenize(sentence))
# Out:
# [('enter', 'NN'),
#  ('flauius', 'NN'),
#  ('murellus', 'NN'),
#  ('and', 'CC'),
#  ('certaine', 'NN'),
#  ('commoners', 'NNS'),
#  ('ouer', 'VBP'),
#  ('the', 'DT'),
#  ('stage', 'NN')]

# %% [markdown]
# #### Using parse tree for POS Tagging

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(pos_tag(word_tokenize(sentence)))
pprint(iob_tagged)
# Out:
# [('enter', 'NN', 'O'),
#  ('flauius', 'NN', 'O'),
#  ('murellus', 'NN', 'O'),
#  ('and', 'CC', 'O'),
#  ('certaine', 'NN', 'O'),
#  ('commoners', 'NNS', 'O'),
#  ('ouer', 'VBP', 'O'),
#  ('the', 'DT', 'O'),
#  ('stage', 'NN', 'O')]

# %%
from nltk import ne_chunk
ne_tree = ne_chunk(pos_tag(word_tokenize(sentence)))
print(ne_tree)
# Out:
# (S
#   enter/NN
#   flauius/NN
#   murellus/NN
#   and/CC
#   certaine/NN
#   commoners/NNS
#   ouer/VBP
#   the/DT
#   stage/NN)

# %%
nouns = []
for i,j in tagged_sent:
    if j == "NOUN" or "NN" in j:
        nouns.append(i)
print(f"The nouns in the text are : {nouns}")
# Out:
# The nouns in the text are : ['enter', 'flauius', 'murellus', 'certaine', 'commoners', 'stage']

# %% [markdown]
# #### Information Retrival
# Amazon Reviews Dataset

# %%
import pandas as pd

review_corpus = pd.read_csv('Restaurant_Reviews.csv')["Review"].to_list()
review_corpus
# Out:
# ['Wow... Loved this place.',
#  'Crust is not good.',
#  'Not tasty and the texture was just nasty.',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#  'The selection on the menu was great and so were the prices.',
#  'Now I am getting angry and I want my damn pho.',
#  "Honeslty it didn't taste THAT fresh.)",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#  'The fries were great too.',
#  'A great touch.',
#  'Service was very prompt.',
#  'Would not go back.',
#  'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.',
#  'I tried the Cape Cod ravoli, chicken, with cranberry...mmmm!',
#  'I was disgusted because I was pretty sure that was human hair.',
#  'I was shocked because no signs indicate cash only.',
#  'Highly recommended.',
#  'Waitress was a little slow in service.',
# ...

# %%
def calc_len(sent):
    return len(sent)

def preprocessed(sent):
    lower_text = sent.lower()
    tokinized_words = nltk.word_tokenize(lower_text)
    punctuation = [',', '.', "\'", '-', "'s", '"', "``", "''","[","]","?",":"]
    stop_words = stopwords.words("english")
    clean_words = [i for i in tokinized_words if i not in punctuation]
    clean_words = [i for i in tokinized_words if i not in stop_words]
    return clean_words

def calc_vocab(sent):
    clean_words = preprocessed(sent)
    return len(set(clean_words))

def calc_nouns(sent):
    tagged_sent = pos_tag(preprocessed(sent))
    nouns = []
    for i,j in tagged_sent:
        if j == "NOUN" or "NN" in j:
            nouns.append(i)
#     print(f"The nouns in the text are : {nouns}")
    return nouns

    
def frequency_count(preped_text):
    word_freq = dict()
    for i  in preped_text:
        if i in word_freq.keys():
            word_freq[i] += 1
        else:
            word_freq[i] = 1
    word_freq = dict(sorted(word_freq.items(), key=lambda item: (item[1],item[0]),reverse=True))
    return word_freq


def most_used_word(sent):
    word_freq = frequency_count(preprocessed(sent))
    return list(word_freq.keys())[0]

def ttr(sent):
    return calc_vocab(sent) / calc_len(sent)

def no_bigrams(sent):
    return len(set(nltk.bigrams(preprocessed(sent))))

def no_trigrams(sent):
    return len(set(nltk.trigrams(preprocessed(sent))))

# %%
# ["Length","Vocab","Freq Words","TTR","Bigrams","Trigrams"]
df = pd.DataFrame()
c = 0 
for sent in review_corpus:
    temp = [calc_len(sent), calc_vocab(sent), most_used_word(
        sent), ttr(sent), no_bigrams(sent), no_trigrams(sent),calc_nouns(sent)]
    df[sent]=temp
    c += 1
# Out:
# <ipython-input-157-9e57f6cafcaf>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[sent]=temp

# %%
df = df.T
df.head()
# Out:
#                                                      0   1          2  \
# Wow... Loved this place.                            24   5        wow
# Crust is not good.                                  18   3       good
# Not tasty and the texture was just nasty.           41   4    texture
# Stopped by during the late May bank holiday off...  87  10    stopped
# The selection on the menu was great and so were...  59   5  selection
#
#                                                            3  4  5  \
# Wow... Loved this place.                            0.208333  4  3
# Crust is not good.                                  0.166667  2  1
# Not tasty and the texture was just nasty.           0.097561  3  2
# Stopped by during the late May bank holiday off...  0.114943  9  8
# The selection on the menu was great and so were...  0.084746  4  3
#
#                                                                                          6
# ...

# %% [markdown]
# >The generated is the features that is extracted from the given amazon reviews that can be used in certain use cases for problems.
